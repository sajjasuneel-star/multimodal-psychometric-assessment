# %% [markdown]
# # Multimodal Psychometric Assessment — Colab Runner
# Upload/extract the project ZIP in Colab, then use this notebook to run the verified implementation.

# %%
# !pip -q install -r ../requirements.txt

# %%
import os, sys
os.chdir("..")
sys.path.insert(0, os.getcwd())
print(os.getcwd())

# %% [markdown]
# ## Quick end-to-end validation

# %%
# !python run_all.py --mode quick --output-dir outputs_quick

# %% [markdown]
# ## Manuscript-scale run
# This can require substantial GPU time because it runs repeated held-out-cohort experiments and baselines.

# %%
# Uncomment for the full paper-scale experiment
#!python run_all.py --mode paper --output-dir outputs_paper
